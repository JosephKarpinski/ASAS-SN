# %%
import webbrowser

webbrowser.open('https://vizier.cds.unistra.fr/viz-bin/VizieR?-source=J/A%2BA/621/A38')
# Out:
# True

# %%
import numpy as np
import pandas as pd
import scipy as sp

import matplotlib.pyplot as plt

from astroquery.gaia import Gaia
from astroquery.simbad import Simbad

import astropy.coordinates as coord
import astropy.units as u

import pyvo as vo

import webbrowser

import starcolorindexSpT 

import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
import astroquery

print("pandas" + str(pd.__version__))
print("numpy"  + str(np.__version__))
print("scipy"  + str(sp.__version__))

print("matplotlib" + str(matplotlib.__version__))

print("astroquery" + str(astroquery.__version__))


print("\n")
# !python --version

print("\n")
# !jupyter --version
# Out:
# pandas1.1.5
# numpy1.24.2
# scipy1.9.3
# matplotlib3.2.2
# astroquery0.4.7.dev8479
#
#
# Python 3.8.5
#
#
# Selected Jupyter core packages...
# IPython          : 8.12.0
# ipykernel        : 6.19.2
# ipywidgets       : 8.0.4
# jupyter_client   : 8.1.0
# jupyter_core     : 5.3.0
# jupyter_server   : 2.5.0
# jupyterlab       : not installed
# nbclient         : 0.5.13
# nbconvert        : 7.3.1
# nbformat         : 5.7.0
# notebook         : 6.5.3
# qtconsole        : 5.4.2
# traitlets        : 5.7.1

# %%
from astroquery.vizier import Vizier

from astropy.table import Table

Vizier.ROW_LIMIT = -1

result = Vizier.query_constraints(catalog='J/A+A/621/A38')    #  Gaia catalogue of hot subluminous stars (39800 rows)

print(result)  # '0:J/A+A/621/A38/catalog' with 89 column(s) and 39800 row(s)
# Out:
# TableList with 1 tables:
# 	'0:J/A+A/621/A38/catalog' with 89 column(s) and 39800 row(s)

# %%
result[0].columns
# Out:
# <TableColumns names=('Name','Gaia','RAJ2000','DEJ2000','Select','SpTypeSim','SpTypeSD','Plx','GMAG','Gmag','BPmag','RPmag','BP-RP','pmRA','pmDE','E_B-V_','AV','FUVmag','NUVmag','VAPASS','BAPASS','gAPASS','rAPASS','iAPASS','uSDSS','gSDSS','rSDSS','iSDSS','zSDSS','uSKYM','vSKYM','gSKYM','rSKYM','iSKYM','zSKYM','uATLAS','gATLAS','rATLAS','iATLAS','zATLAS','uVPHAS','gVPHAS','r2VPHAS','HaVPHAS','rVPHAS','iVPHAS','uKiDS','gKiDS','rKiDS','iKiDS','gPS1','rPS1','iPS1','zPS1','yPS1','rIPHAS','iIPHAS','HaIPHAS','J2MASS','H2MASS','K2MASS','YUKIDSS','JUKIDSS','HUKIDSS','KUKIDSS','YVHS','JVHS','HVHS','KsVHS','ZVVV','YVVV','JVVV','HVVV','KsVVV','ZVIKING','YVIKING','JVIKING','HVIKING','KsVIKING','W1mag','W2mag','W3mag','W4mag','Dens','epsi','sepsi','amax','E_BR_RP_','SED')>

# %%
list_columns = ['Name','Gaia','RAJ2000','DEJ2000','Select','SpTypeSim','SpTypeSD','Plx','GMAG','Gmag','BPmag','RPmag','BP-RP','pmRA','pmDE','E_B-V_','AV','FUVmag','NUVmag','VAPASS','BAPASS','gAPASS','rAPASS','iAPASS','uSDSS','gSDSS','rSDSS','iSDSS','zSDSS','uSKYM','vSKYM','gSKYM','rSKYM','iSKYM','zSKYM','uATLAS','gATLAS','rATLAS','iATLAS','zATLAS','uVPHAS','gVPHAS','r2VPHAS','HaVPHAS','rVPHAS','iVPHAS','uKiDS','gKiDS','rKiDS','iKiDS','gPS1','rPS1','iPS1','zPS1','yPS1','rIPHAS','iIPHAS','HaIPHAS','J2MASS','H2MASS','K2MASS','YUKIDSS','JUKIDSS','HUKIDSS','KUKIDSS','YVHS','JVHS','HVHS','KsVHS','ZVVV','YVVV','JVVV','HVVV','KsVVV','ZVIKING','YVIKING','JVIKING','HVIKING','KsVIKING','W1mag','W2mag','W3mag','W4mag','Dens','epsi','sepsi','amax','E_BR_RP_','SED']

# %%
import pandas as pd

list = []

list = result[result.keys()[0]]

df = pd.DataFrame.from_records(list, columns=list_columns)

# %%
df.head()
# Out:
#                       Name                          Gaia   RAJ2000    DEJ2000  \
# 0                    SB937  Gaia DR2 2313054538477276160  0.016782 -33.588654
# 1                   PHL615  Gaia DR2 2414485448212792064  0.021629 -17.147625
# 2               PG2357+174  Gaia DR2 2773760665114010880  0.065659  17.648045
# 3  UVEXJ000016.27+603246.3   Gaia DR2 429345443672003072  0.067773  60.546199
# 4              HS2357+2201  Gaia DR2 2847977322031768832  0.076685  22.300821
#
#          Select SpTypeSim SpTypeSD     Plx    GMAG       Gmag  ...   W1mag  \
# 0  COLOUR_REDPM        A0           0.2431  1.1628  14.233900  ...  14.289
# 1  COLOUR_REDPM   sdO5He4      sdO  0.2363      --  16.798401  ...      --
# 2  COLOUR_REDPM       sdB      sdB  0.4881  4.9884  16.545900  ...  16.969
# 3    COLOUR_PLX       sdB           0.7556  5.9593  16.567801  ...      --
# 4    COLOUR_PLX       sdB      sdB  1.0670  4.3781  14.236300  ...  14.933
#
#     W2mag   W3mag  W4mag        Dens      epsi      sepsi      amax  E_BR_RP_  \
# 0   14.28  12.644   8.75   2484.7498  0.277000  14.520544  0.092586  1.188000
# 1      --      --     --   3024.4438  0.316000   3.537208  0.161034  1.243000
# 2  16.614  12.541  8.889   4105.8315  0.353000   5.738525  0.217278  1.244000
# 3      --      --     --  76111.2340  0.189899   1.505587  0.092514  1.223866
# 4  15.118  12.288  9.105   5186.1606  0.389168  27.937053  0.125877  1.210584
#
#    SED
# 0  SED
# 1  SED
# 2  SED
# 3  SED
# 4  SED
#
# [5 rows x 89 columns]

# %%
df.to_csv('Gaia_catalogue_of_hot_subluminous_stars_39800.csv')

# %%
from IPython.display import display, HTML
display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
make_canvas_flag = "Y"

hydrogen_lines_flag = "N"

# %%
def make_labels(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

# %%
def make_RVS_canvas(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 1.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('Ca II 8498', xy=[8498, yRangeMin ],  rotation=-90, color='red')
    plt.annotate('Ca II 8542', xy=[8542, yRangeMin ], rotation=-90, color='red')
    plt.annotate('Pa14 8600', xy=[8600, yRangeMin - 0.3 ], rotation=-90, color='red')
    plt.annotate('Ca II 8662.1', xy=[8662, yRangeMin ],  rotation=-90, color='red')

# %%
# Plotter ==============================================
def make_canvas(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    plt.xticks([3839, 3889, 3970, 4101, 4340, 4472, 4861, 5175, 5270, 5411, 5755, 5895, 6302,
               6365, 6562, 6562, 6890, 7135, 7500, 7775, 8000, 8498, 8542, 8662, 9000, 9200])
    
    xLabels = (3839, 3889, 3970, 4101, 4340, 4472, 4861, 5175, 5270, 5411, 5755, 5895, 6302,
               6365, 6562, 6562, 6890, 7135, 7500, 7775, 8000, 8498, 8542, 8662, 9000, 9200)

    plt.xticks(xLabels, rotation=90)

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 0.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('CN 3839', xy=[3839,   yRangeMin + 0.6],  rotation=-90)
    plt.annotate('H-zeta 3889', xy=[3889, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-epsilon 3970', xy=[3970, yRangeMin +  0.6],  rotation=-90, color='red')
    plt.annotate('H-delta 4101', xy=[4101, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-gamma 4340', xy=[4340, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('He I 4471.7', xy=[4472, yRangeMin + .20],  rotation=-90, color='orange')
    plt.annotate('H-beta 4861', xy=[4861, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('Mg I 5175', xy=[5175, yRangeMin + .20],  rotation=-90)
    plt.annotate('Fe I 5270', xy=[5270, yRangeMin +  .20],  rotation=-90)
    plt.annotate('He II 5411', xy=[5411, yRangeMin +  .20],  rotation=-90, color='orange')
    plt.annotate('N II 5755', xy=[5755, yRangeMin +  .20],  rotation=-90)
    plt.annotate('D1 Na I 5895', xy=[5895, yRangeMin +  .20],  rotation=-90, color='blue')
    plt.annotate('OI 6302', xy=[6302, yRangeMin +  .20],  rotation=-90, color='green')
    plt.annotate('OI 6365.5', xy=[6365, yRangeMin +  .20],  rotation=-90, color='green')
    plt.annotate('H-alpha 6562', xy=[6562, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('CN 6890', xy=[6890, yRangeMin +  .20],  rotation=-90)
    plt.annotate('Ar III 7135', xy=[7135, yRangeMin +  .20],  rotation=-90)
    plt.annotate('O I 7775', xy=[7775, yRangeMin +  .20], rotation=-90, color='green')
    plt.annotate('Ca II 8498', xy=[8498, yRangeMin +  .35],  rotation=-90, color='blue')
    plt.annotate('Ca II 8542', xy=[8542, yRangeMin +  .30], rotation=-90, color='blue')
    plt.annotate('Ca II 8662.1', xy=[8662, yRangeMin +  .30],  rotation=-90, color='blue')


def Hydrogen_lines(xlabel = '', ylabel = '', fontsize = 12):
    #plt.xlabel(xlabel,  fontsize = fontsize)
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    plt.xticks([3835, 3889, 3970, 4101, 4340, 4861, 6000, 6562, 7000, 8000, 9000, 10000])
    
    xLabels = (3835, 3889, 3970, 4101, 4340, 4861, 6000, 6562, 7000, 8000, 9000, 10000)

    plt.xticks(xLabels, rotation=90)

    yMin = float(xp['flux'].min())
    #yRangeMin = yMin + 0.2
    yRangeMin = 0.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('H12 3750', xy=[3750, yRangeMin +  .50],  rotation=-90, color='red')
    plt.annotate('H11 3771', xy=[3771, yRangeMin -  .35],  rotation=-90, color='red')
    plt.annotate('H10 3798', xy=[3798, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H9 3835', xy=[3835, yRangeMin -  .10],  rotation=-90, color='red')

    plt.annotate('H8-zeta 3889', xy=[3889, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-epsilon 3970', xy=[3970, yRangeMin +  0.6],  rotation=-90, color='red')
    plt.annotate('H-delta 4101', xy=[4101, yRangeMin +  .20],  rotation=-90, color='red')
    plt.annotate('H-gamma 4340', xy=[4340, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('H-beta 4861', xy=[4861, yRangeMin + .20],  rotation=-90, color='red')
    plt.annotate('H-alpha 6562', xy=[6562, yRangeMin +  .20],  rotation=-90, color='red')

# %%
def make_RVS_canvas1(xlabel = '', ylabel = '', fontsize = 12):     ### 8460 - 8580
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    yMin = float(xp['flux'].min())
    yRangeMin = 1.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('Fe I 8470', xy=[8470, yRangeMin ],  rotation=-90, color='green')
    plt.annotate('Mg I 8476', xy=[8476, yRangeMin - 0.3],  rotation=-90, color='blue')
    plt.annotate('Fe I 8483', xy=[8483, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Ca II 8498', xy=[8498, yRangeMin ],  rotation=-90, color='red')
    plt.annotate('Ca II 8502', xy=[8502, yRangeMin],  rotation=-90, color='red')
    plt.annotate('Ce II 8514', xy=[8514, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Fe I 8516', xy=[8516, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Ti I 8520.6', xy=[8520.6, yRangeMin - 0.3],  rotation=-90, color='blue')
    plt.annotate('Zr II 8527', xy=[8527, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Fe I 8529', xy=[8529, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Si I 8538', xy=[8538, yRangeMin - 0.3],  rotation=-90, color='red')
    plt.annotate('Ca II 8542', xy=[8542, yRangeMin],  rotation=-90, color='red')
    plt.annotate('Ca II 8546', xy=[8546, yRangeMin - 0.3],  rotation=-90, color='red')
    plt.annotate('Cr I 8551', xy=[8551, yRangeMin  - 0.3],  rotation=-90, color='green')
    plt.annotate('Si I 8559', xy=[8559, yRangeMin  - 0.3],  rotation=-90, color='red')
    plt.annotate('Ti I 8572', xy=[8572, yRangeMin - 0.3],  rotation=-90, color='blue')
    plt.annotate('Fe I 8574', xy=[8574, yRangeMin - 0.3],  rotation=-90, color='green')

# %%
def make_RVS_canvas2(xlabel = '', ylabel = '', fontsize = 12):    ### 8580 - 8700
    plt.xlabel("Wavelength [Angstroms]",  fontsize = fontsize)
    plt.ylabel(ylabel, fontsize = fontsize)
    plt.xticks(fontsize = fontsize)
    plt.yticks(fontsize = fontsize)
    plt.grid()

    yMin = float(xp['flux'].min())
    yRangeMin = 1.8 

    yRangeMax = float(xp['flux'].max())
    yRange = yRangeMax

    plt.annotate('Fe I 8584', xy=[8584, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Fe II 8588', xy=[8588, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Nd II 8594', xy=[8594, yRangeMin - 0.3],  rotation=-90, color='blue')
    plt.annotate('Fe I 8624', xy=[8624, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('N I 8631',  xy=[8631, yRangeMin  - 0.3 ],  rotation=-90, color='red')
    plt.annotate('Ca I 8636',  xy=[8636, yRangeMin  - 0.3 ],  rotation=-90, color='red')
    plt.annotate('Ni I 8639',  xy=[8639, yRangeMin  - 0.3 ],  rotation=-90, color='red')
    plt.annotate('Cr I 8645', xy=[8645, yRangeMin  - 0.3],  rotation=-90, color='green')
    plt.annotate('Ca II 8662', xy=[8662, yRangeMin],  rotation=-90, color='red')
    plt.annotate('Ca II 8666', xy=[8666, yRangeMin],  rotation=-90, color='red')
    plt.annotate('S I 8672',  xy=[8672, yRangeMin  - 0.3],  rotation=-90, color='red')
    plt.annotate('Fe I 8677', xy=[8677, yRangeMin],  rotation=-90, color='green')
    plt.annotate('N I 8685',  xy=[8685, yRangeMin  - 0.3],  rotation=-90, color='red')
    plt.annotate('Si I 8688', xy=[8688, yRangeMin  - 0.3],  rotation=-90, color='red')
    plt.annotate('Fe I 8691', xy=[8691, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('Ti I 8694', xy=[8694, yRangeMin - 0.3],  rotation=-90, color='green')
    plt.annotate('S I 8697',  xy=[8697, yRangeMin  - 0.3 ],  rotation=-90, color='red')

# %%
# https://vizier.cds.unistra.fr/viz-bin/VizieR?-source=J/A%2BA/621/A38

df_hot_subluminous = pd.read_csv('Gaia_catalogue_of_hot_subluminous_stars_39800.csv')

df_hot_subluminous.shape[0]
# Out:
# 39800

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

df_hot_subluminous.head(5)
# Out:
#    Unnamed: 0                     Name                          Gaia  \
# 0           0                    SB937  Gaia DR2 2313054538477276160
# 1           1                   PHL615  Gaia DR2 2414485448212792064
# 2           2               PG2357+174  Gaia DR2 2773760665114010880
# 3           3  UVEXJ000016.27+603246.3   Gaia DR2 429345443672003072
# 4           4              HS2357+2201  Gaia DR2 2847977322031768832
#
#     RAJ2000    DEJ2000        Select SpTypeSim SpTypeSD     Plx    GMAG  \
# 0  0.016782 -33.588654  COLOUR_REDPM        A0      NaN  0.2431  1.1628
# 1  0.021629 -17.147625  COLOUR_REDPM   sdO5He4      sdO  0.2363      --
# 2  0.065659  17.648045  COLOUR_REDPM       sdB      sdB  0.4881  4.9884
# 3  0.067773  60.546199    COLOUR_PLX       sdB      NaN  0.7556  5.9593
# 4  0.076685  22.300821    COLOUR_PLX       sdB      sdB  1.0670  4.3781
#
#         Gmag      BPmag      RPmag   BP-RP   pmRA    pmDE  E_B-V_      AV  \
# 0  14.233900  14.185200  14.246800 -0.0616  4.593 -12.837  0.0125  0.0387
# 1  16.798401  16.550301  17.102800 -0.5526  8.049 -10.354  0.0193  0.0597
# 2  16.545900  16.318899  16.790001 -0.4711  6.468  -2.756  0.0242  0.0749
# 3  16.567801  16.552000  16.438299  0.1138  1.614  -3.009  1.0818  3.3536
# 4  14.236300  14.072500  14.425200 -0.3527  5.517 -11.984  0.0578  0.1793
#
#    FUVmag  NUVmag  VAPASS  BAPASS  gAPASS  rAPASS  iAPASS   uSDSS   gSDSS  \
# 0  16.002  15.593  14.182  14.182  14.086  14.301  14.546      --      --
# 1      --  15.673      --      --      --      --      --      --      --
# 2  15.286  15.479   16.62  16.401  16.348  16.764      --   15.99  16.321
# 3      --   17.41      --      --      --      --      --      --      --
# 4  13.529  13.694  14.283    14.1  14.048  14.441  14.748  13.916  14.007
#
#     rSDSS   iSDSS   zSDSS   uSKYM   vSKYM   gSKYM   rSKYM   iSKYM   zSKYM  \
# 0      --      --      --  15.177  14.394   14.11  14.302  14.607  14.745
# 1      --      --      --  16.195  16.313  16.636  16.957  17.462  17.788
# 2  16.797  17.157  17.445      --      --      --      --      --      --
# 3      --      --      --      --      --      --      --      --      --
# 4  14.425   14.73  15.014      --      --      --      --      --      --
#
#     uATLAS gATLAS   rATLAS   iATLAS   zATLAS uVPHAS gVPHAS r2VPHAS HaVPHAS  \
# 0  14.7445  14.13  14.3948  14.5877  14.6403     --     --      --      --
# 1       --     --       --       --       --     --     --      --      --
# 2       --     --       --       --       --     --     --      --      --
# 3       --     --       --       --       --     --     --      --      --
# 4       --     --       --       --       --     --     --      --      --
#
#   rVPHAS iVPHAS     uKiDS gKiDS rKiDS iKiDS     gPS1     rPS1     iPS1  \
# 0     --     --  14.99557    --    --    --    14.34   14.498  14.5978
# 1     --     --        --    --    --    --   16.602   17.034  17.4196
# 2     --     --        --    --    --    --  16.3488  16.7591  17.1289
# 3     --     --        --    --    --    --  16.6059  16.6535  16.7833
# 4     --     --        --    --    --    --  14.0853  14.4383  14.7667
#
#       zPS1     yPS1 rIPHAS iIPHAS HaIPHAS  J2MASS  H2MASS  K2MASS YUKIDSS  \
# 0   14.819   14.873     --     --      --  14.248   14.17  14.177      --
# 1  17.6887  17.8594     --     --      --      --      --      --      --
# 2  17.3868  17.5781     --     --      --      --      --      --      --
# 3    16.91  17.0069  16.55  16.47   16.43  16.493  16.147  16.049      --
# 4  15.0061  15.1728     --     --      --  14.774  15.076  14.866      --
#
#   JUKIDSS HUKIDSS KUKIDSS      YVHS      JVHS HVHS     KsVHS ZVVV YVVV JVVV  \
# 0      --      --      --        --        --   --        --   --   --   --
# 1      --      --      --  17.38003  17.53805   --  17.78974   --   --   --
# 2      --      --      --        --        --   --        --   --   --   --
# 3      --      --      --        --        --   --        --   --   --   --
# 4      --      --      --        --        --   --        --   --   --   --
#
#   HVVV KsVVV   ZVIKING   YVIKING   JVIKING   HVIKING  KsVIKING   W1mag  \
# 0   --    --  14.19539  14.20024  14.24117  14.28746  14.28081  14.289
# 1   --    --        --        --        --        --        --      --
# 2   --    --        --        --        --        --        --  16.969
# 3   --    --        --        --        --        --        --      --
# 4   --    --        --        --        --        --        --  14.933
#
#     W2mag   W3mag  W4mag        Dens      epsi      sepsi      amax  E_BR_RP_  \
# 0   14.28  12.644   8.75   2484.7498  0.277000  14.520544  0.092586  1.188000
# 1      --      --     --   3024.4438  0.316000   3.537208  0.161034  1.243000
# 2  16.614  12.541  8.889   4105.8315  0.353000   5.738525  0.217278  1.244000
# 3      --      --     --  76111.2340  0.189899   1.505587  0.092514  1.223866
# 4  15.118  12.288  9.105   5186.1606  0.389168  27.937053  0.125877  1.210584
#
#    SED
# 0  SED
# 1  SED
# 2  SED
# 3  SED
# 4  SED

# %%
df_hot_subluminous['source_id']= df_hot_subluminous['Gaia'].str[9:]

# %%
df_hot_subluminous[['Gaia','source_id']].head(5)
# Out:
#                            Gaia            source_id
# 0  Gaia DR2 2313054538477276160  2313054538477276160
# 1  Gaia DR2 2414485448212792064  2414485448212792064
# 2  Gaia DR2 2773760665114010880  2773760665114010880
# 3   Gaia DR2 429345443672003072   429345443672003072
# 4  Gaia DR2 2847977322031768832  2847977322031768832

# %%
unique_variable_sim = np.unique(df_hot_subluminous['SpTypeSim'].astype(str))

# %%
unique_variable_sim
# Out:
# array(['A', 'A/DAZ', 'A/sdB', 'A0', 'A0.0', 'A0.1', 'A0III', 'A0III/IV',
#        'A0IV', 'A0IV/V', 'A0V', 'A0Vn', 'A1', 'A1/2V', 'A1V', 'A1Vn',
#        'A2', 'A2/3(IV)', 'A2II', 'A2IV/V', 'A3', 'A4/5V', 'A4V', 'A5',
#        'A5/8', 'A5mA5-F2', 'A7', 'A7IV', 'A?', 'ApSi', 'B', 'B/DAZ',
#        'B/sdB', 'B/sdB:', 'B0', 'B0-1Ia', 'B0-5(III)e', 'B0.5:I', 'B0.5I',
#        'B0.5Ia', 'B0.5Ib', 'B0.7I', 'B0I', 'B0Ia', 'B0V', 'B1', 'B1.5Ia',
#        'B1.5Iab', 'B1.5Ib', 'B1/2(III)', 'B1::I', 'B1III', 'B1Ia',
#        'B1Ib(e)', 'B2', 'B2.7', 'B2/5V?', 'B2He', 'B2He?', 'B2II',
#        'B2III/IV', 'B2Iab', 'B2Ib', 'B2V', 'B2Ve', 'B2p', 'B3', 'B3.8',
#        'B3.9', 'B3/5V', 'B3II', 'B3III', 'B3IV', 'B4', 'B4.1', 'B4.2',
#        'B4.5', 'B4/sdB', 'B4?', 'B4V', 'B4e', 'B5', 'B5.0', 'B5.1',
#        'B5.3', 'B5.4', 'B5.5', 'B5.6', 'B5.7', 'B5.9', 'B5/7II/III',
#        'B5I', 'B5III', 'B5Iab', 'B5V:', 'B5Vp', 'B5e', 'B6', 'B6.1',
#        'B6.2', 'B6.3', 'B6.6', 'B6.9', 'B6/sd?', 'B6:', 'B7', 'B7.0',
#        'B7.3', 'B7.4', 'B7.5', 'B7/8V', 'B7V', 'B8', 'B8.2', 'B8.7',
#        'B8/9II', 'B8/9II/III', 'B8/9V', 'B8III', 'B8Iab', 'B8V', 'B9',
#        'B9.1', 'B9.2', 'B9.3', 'B9.4', 'B9.5V', 'B9.6', 'B9.7', 'B9.8',
#        'B9.9', 'B9/9.5V', 'B9/A0V', 'B9II/III', 'B9III', 'B9IV', 'B9IV/V',
#        'B9V', 'B9kp', 'B9w', 'B:', 'B?', 'BHe', 'BHe?', 'BIb', 'BN',
#        'BN1', 'BN2', 'BN3', 'BV', 'BVI', 'Be', 'Bp', 'Bpec', 'D', 'D+K',
#        'DA', 'DA(O?)', 'DA+M', 'DA+M:', 'DA+dM', 'DA+dM:e', 'DA+dMe',
#        'DA/sdB', 'DA/sdB+K1?', 'DA/sdB+K4?', 'DA/sdB+K5?', 'DA0', 'DA1',
#        'DA1-2', 'DA1:', 'DA2', 'DA2:', 'DA3', 'DA3.5', 'DA4', 'DA:',
#        'DA:/sd', 'DAB', 'DAB/sdB', 'DAB:', 'DABZ', 'DAO', 'DAO+M:',
#        'DAO.5', 'DAO.57', 'DAO.6', 'DAO.70', 'DAO.8', 'DAO/sdO', 'DAO0.5',
#        'DAO1', 'DAO:', 'DAP', 'DAZ', 'DAZ:', 'DAe', 'DAwk', 'DAwk?', 'DB',
#        'DB3', 'DBA', 'DBA4', 'DBA:', 'DBA?', 'DBAZ', 'DBP3', 'DBnnp',
#        'DC', 'DC:', 'DO', 'DO/B', 'DO/sdO', 'DO/sdOHe', 'DO1', 'DO?',
#        'DOA/sdBHe', 'DOQZ1', 'DOZ', 'DOZ1', 'F', 'F+sd?', 'F+sdB', 'F0',
#        'F2+?', 'F8', 'F?', 'G', 'G0:', 'G1', 'G5', 'G8V', 'K1', 'M3-9',
#        'M5', 'M9', 'O', 'O3?O4v((f))', 'O7.5', 'O7fk', 'O7fp', 'O7p',
#        'O8p', 'O9.5', 'O9.5I', 'O9.7Ia', 'O9If', 'O9k', 'O?', 'OB', 'OB+',
#        'OB+e:', 'OB-', 'OB-n', 'OB-nn', 'OB:', 'OBe', 'Oe', 'Oev:',
#        'Ofpe/WN9', 'Opk', 'PCyg', 'PG1159', 'PG1159/O(He)', 'SdB+M',
#        'WN7', 'WNE', '[WC4]', '[WC5]', '[WC]', '[WO1]', 'dF',
#        'kA1.5hA3mA3Va', 'nan', 'sd', 'sd+', 'sd:', 'sdA', 'sdB',
#        'sdB(+F?)', 'sdB(?)', 'sdB(e?)', 'sdB+', 'sdB+?', 'sdB+D',
#        'sdB+DA', 'sdB+F', 'sdB+F/G', 'sdB+F0?kA0', 'sdB+F2:kA2',
#        'sdB+F2:kA3', 'sdB+F2:kA5', 'sdB+F2?kA2', 'sdB+F5gF2kA2',
#        'sdB+F6V', 'sdB+F7V', 'sdB+F8V', 'sdB+F9', 'sdB+F?', 'sdB+G',
#        'sdB+G0', 'sdB+G0IV', 'sdB+G0V', 'sdB+G1', 'sdB+G1V', 'sdB+G3',
#        'sdB+G4', 'sdB+G4V', 'sdB+G5', 'sdB+G7V', 'sdB+G8', 'sdB+G9',
#        'sdB+G9V', 'sdB+G:', 'sdB+K0', 'sdB+K3', 'sdB+dM', 'sdB/A',
#        'sdB/B', 'sdB/B2?', 'sdB/DA', 'sdB/OB', 'sdB/OB?', 'sdB/OHe',
#        'sdB0', 'sdB0.2VIHe3', 'sdB0.2VIIHe12', 'sdB0.2VIIHe3',
#        'sdB0.2VIIHe39', 'sdB0.2VIIHe9', 'sdB0.2VIIIpHe8', 'sdB0.2VIeHe7',
#        'sdB0.5VHe10', 'sdB0.5VHe2', 'sdB0.5VIIHe11', 'sdB0.5VIIHe18',
#        'sdB0.5VIIHe19', 'sdB0.5VIIHe7', 'sdB0.5VIIIHe7', 'sdB0.5VpHe7',
#        'sdB0/1', 'sdB0VIIHe0', 'sdB0VIIHe8', 'sdB0VIIHe9', 'sdB0VIIpHe10',
#        'sdB1(k)', 'sdB1.5VIIHe0', 'sdB1.5VIIHe1', 'sdB1.5VIIHe2',
#        'sdB1.5VIIHe3', 'sdB1.5VIIHe4', 'sdB1.5VIIHe5', 'sdB1.5VIIHe9',
#        'sdB1.5VIIIpHe0', 'sdB1:', 'sdB1VIHe0', 'sdB1VIHe13', 'sdB1VIIHe0',
#        'sdB1VIIHe10', 'sdB1VIIHe35', 'sdB1VIIHe39', 'sdB1VIIHe4',
#        'sdB1VIIHe5', 'sdB1VIIHe6', 'sdB1VIIHe9', 'sdB1VIIIHe0',
#        'sdB1VIIeHe1', 'sdB2', 'sdB2.5IVHe11', 'sdB2.5VHe7',
#        'sdB2.5VIIHe3', 'sdB2.5VIIeHe3', 'sdB2VIHe2', 'sdB2VIHe3',
#        'sdB2VIHe4', 'sdB2VIIHe0', 'sdB2VIIHe3', 'sdB2VIIHe4',
#        'sdB2VIIHe5', 'sdB2VIIHe6', 'sdB2VIIHe7', 'sdB2VIIIpHe0',
#        'sdB2VIIpHe4', 'sdB3IHe8', 'sdB3IVHe5', 'sdB3VHe13', 'sdB3VHe15',
#        'sdB3VIHe6', 'sdB3VIIHe0', 'sdB3VIIHe3', 'sdB3VIIHe4', 'sdB4',
#        'sdB5IIIHe11', 'sdB5IIIHe4', 'sdB5IIIHe5', 'sdB5IIIHe7',
#        'sdB5IVHe7', 'sdB6', 'sdB7IIIHe3', 'sdB7IVeHe3', 'sdB7VHe6',
#        'sdB8IIIHe2', 'sdB8IVHe0', 'sdB8IVHe1', 'sdB:', 'sdB?', 'sdB?/DA?',
#        'sdB?/DAwk?', 'sdB?He', 'sdBC0.2VIIHe22', 'sdBC0.2VIIHe24',
#        'sdBC0.2VIIHe26', 'sdBC0.2VIIHe27', 'sdBC0.2VIIHe28',
#        'sdBC0.5VIIHe28', 'sdBC1VHe38', 'sdBC1VIIHe34', 'sdBC1VIIpHe39',
#        'sdBHe', 'sdBHe+F?', 'sdBHe0', 'sdBHe0+F/G', 'sdBHe1',
#        'sdBHe1+F/G', 'sdBHe1+F/G?', 'sdBHe:', 'sdBN0.2VIIHe29',
#        'sdBN0.2VIIHe38', 'sdBN0.2VIIHe39', 'sdBN0VIIHe28', 'sdBN0VIIHe35',
#        'sdBN0VIIHe37', 'sdBN0VIIHe38', 'sdBN0VIIHe39', 'sdBN1VIIHe37',
#        'sdBO', 'sdBOHe', 'sdBV', 'sdBe', 'sdBe?', 'sdBp', 'sdBpec', 'sdO',
#        'sdO(He)', 'sdO+F', 'sdO+F/G', 'sdO+F2:kA1', 'sdO+F3V', 'sdO+F6V',
#        'sdO+G', 'sdO+G1V', 'sdO+G:', 'sdO+dM', 'sdO2VIIHe14',
#        'sdO2VIIIHe1', 'sdO2VIIIHe40', 'sdO2VIIIHe5', 'sdO2VIeHe11',
#        'sdO2VIeHe12', 'sdO3:', 'sdO3VIIIpHe1', 'sdO3VIIeHe40', 'sdO4He1',
#        'sdO4He2', 'sdO5', 'sdO5He4', 'sdO5VIHe1', 'sdO5VIepHe2', 'sdO6',
#        'sdO6.5VIIpHe35', 'sdO6He', 'sdO6He1', 'sdO6He2', 'sdO6He4',
#        'sdO7', 'sdO7?He3', 'sdO7He1', 'sdO7He1+F/G', 'sdO7He2', 'sdO7He3',
#        'sdO7VIHe1', 'sdO7VIIHe1', 'sdO7VIIHe40', 'sdO7VIIIHe36',
#        'sdO8He1', 'sdO8He3', 'sdO8He4', 'sdO8VIHe1', 'sdO8VIIHe0',
#        'sdO8VIIHe1', 'sdO8VIIHe40', 'sdO8VIIIHe0', 'sdO8VIIIHe5',
#        'sdO8VIIIHe7', 'sdO8VIepHe1', 'sdO8VpHe19', 'sdO8p', 'sdO9VHe17',
#        'sdO9VIIHe39', 'sdO9VIIHe6', 'sdO9VIIIHe0', 'sdO9VIIIHe10', 'sdO:',
#        'sdO?', 'sdO?He', 'sdOA', 'sdOA:', 'sdOB', 'sdOB+F', 'sdOB+G',
#        'sdOB+G2V', 'sdOB+G?', 'sdOB/B', 'sdOB/O9', 'sdOB:', 'sdOB?',
#        'sdOBe', 'sdOC', 'sdOC1VIIHe40', 'sdOC2VIIIHe36', 'sdOC2VIIIHe40',
#        'sdOC2VIIeHe40', 'sdOC2VIeHe40', 'sdOC6.5VIIHe40', 'sdOC7VIIHe40',
#        'sdOC7VIIeHe40', 'sdOC8VIIHe39', 'sdOC9.5VIIHe39', 'sdOC9VIIHe40',
#        'sdOC:', 'sdOD', 'sdOHe', 'sdOHe/DO', 'sdOe', 'sdOp', 'sdOpec'],
#       dtype=object)

# %%
for vartype in unique_variable_sim:
    v = df_hot_subluminous[df_hot_subluminous['SpTypeSim'] == vartype]
    print(str(vartype) + "  count: "  + str(v.shape[0]))
# Out:
# A  count: 20
# A/DAZ  count: 12
# A/sdB  count: 8
# A0  count: 40
# A0.0  count: 1
# A0.1  count: 1
# A0III  count: 1
# A0III/IV  count: 1
# A0IV  count: 2
# A0IV/V  count: 2
# A0V  count: 8
# A0Vn  count: 1
# A1  count: 3
# A1/2V  count: 1
# A1V  count: 2
# A1Vn  count: 1
# A2  count: 9
# A2/3(IV)  count: 1
# A2II  count: 1
# A2IV/V  count: 1
# A3  count: 3
# A4/5V  count: 1
# A4V  count: 1
# A5  count: 3
# A5/8  count: 1
# A5mA5-F2  count: 1
# A7  count: 3
# A7IV  count: 1
# A?  count: 1
# ApSi  count: 1
# B  count: 527
# B/DAZ  count: 2
# B/sdB  count: 12
# B/sdB:  count: 2
# B0  count: 4
# B0-1Ia  count: 1
# B0-5(III)e  count: 1
# B0.5:I  count: 1
# B0.5I  count: 1
# B0.5Ia  count: 1
# B0.5Ib  count: 1
# B0.7I  count: 1
# B0I  count: 2
# B0Ia  count: 1
# B0V  count: 3
# B1  count: 16
# B1.5Ia  count: 1
# B1.5Iab  count: 2
# B1.5Ib  count: 1
# B1/2(III)  count: 1
# B1::I  count: 1
# B1III  count: 1
# B1Ia  count: 2
# B1Ib(e)  count: 1
# B2  count: 24
# B2.7  count: 1
# B2/5V?  count: 1
# B2He  count: 1
# B2He?  count: 1
# B2II  count: 2
# B2III/IV  count: 1
# B2Iab  count: 1
# B2Ib  count: 1
# B2V  count: 1
# B2Ve  count: 1
# B2p  count: 1
# B3  count: 11
# B3.8  count: 1
# B3.9  count: 1
# B3/5V  count: 1
# B3II  count: 1
# B3III  count: 1
# B3IV  count: 1
# B4  count: 9
# B4.1  count: 2
# B4.2  count: 1
# B4.5  count: 1
# B4/sdB  count: 1
# B4?  count: 1
# B4V  count: 1
# B4e  count: 1
# B5  count: 22
# B5.0  count: 1
# B5.1  count: 1
# B5.3  count: 1
# B5.4  count: 1
# B5.5  count: 1
# B5.6  count: 1
# B5.7  count: 1
# B5.9  count: 1
# B5/7II/III  count: 1
# B5I  count: 1
# B5III  count: 2
# B5Iab  count: 1
# B5V:  count: 1
# B5Vp  count: 1
# B5e  count: 1
# B6  count: 18
# B6.1  count: 1
# B6.2  count: 1
# B6.3  count: 1
# B6.6  count: 1
# B6.9  count: 1
# B6/sd?  count: 1
# B6:  count: 1
# B7  count: 7
# B7.0  count: 1
# B7.3  count: 1
# B7.4  count: 2
# B7.5  count: 1
# B7/8V  count: 1
# B7V  count: 1
# B8  count: 13
# B8.2  count: 1
# B8.7  count: 1
# B8/9II  count: 1
# B8/9II/III  count: 1
# B8/9V  count: 1
# B8III  count: 2
# B8Iab  count: 1
# B8V  count: 2
# B9  count: 17
# B9.1  count: 1
# B9.2  count: 1
# B9.3  count: 1
# B9.4  count: 1
# B9.5V  count: 2
# B9.6  count: 2
# B9.7  count: 1
# B9.8  count: 1
# B9.9  count: 1
# B9/9.5V  count: 1
# B9/A0V  count: 1
# B9II/III  count: 1
# B9III  count: 4
# B9IV  count: 3
# B9IV/V  count: 3
# B9V  count: 5
# B9kp  count: 1
# B9w  count: 1
# B:  count: 1
# B?  count: 1
# BHe  count: 3
# BHe?  count: 1
# BIb  count: 1
# BN  count: 7
# BN1  count: 1
# BN2  count: 1
# BN3  count: 1
# BV  count: 1
# BVI  count: 1
# Be  count: 1
# Bp  count: 1
# Bpec  count: 2
# D  count: 4
# D+K  count: 1
# DA  count: 230
# DA(O?)  count: 1
# DA+M  count: 6
# DA+M:  count: 1
# DA+dM  count: 1
# DA+dM:e  count: 2
# DA+dMe  count: 1
# DA/sdB  count: 2
# DA/sdB+K1?  count: 1
# DA/sdB+K4?  count: 1
# DA/sdB+K5?  count: 1
# DA0  count: 1
# DA1  count: 7
# DA1-2  count: 1
# DA1:  count: 4
# DA2  count: 6
# DA2:  count: 1
# DA3  count: 5
# DA3.5  count: 1
# DA4  count: 3
# DA:  count: 26
# DA:/sd  count: 8
# DAB  count: 73
# DAB/sdB  count: 12
# DAB:  count: 33
# DABZ  count: 1
# DAO  count: 57
# DAO+M:  count: 1
# DAO.5  count: 2
# DAO.57  count: 1
# DAO.6  count: 4
# DAO.70  count: 1
# DAO.8  count: 1
# DAO/sdO  count: 22
# DAO0.5  count: 1
# DAO1  count: 1
# DAO:  count: 1
# DAP  count: 3
# DAZ  count: 4
# DAZ:  count: 3
# DAe  count: 1
# DAwk  count: 2
# DAwk?  count: 1
# DB  count: 19
# DB3  count: 1
# DBA  count: 2
# DBA4  count: 1
# DBA:  count: 2
# DBA?  count: 2
# DBAZ  count: 1
# DBP3  count: 1
# DBnnp  count: 1
# DC  count: 5
# DC:  count: 1
# DO  count: 19
# DO/B  count: 1
# DO/sdO  count: 2
# DO/sdOHe  count: 1
# DO1  count: 1
# DO?  count: 1
# DOA/sdBHe  count: 1
# DOQZ1  count: 1
# DOZ  count: 1
# DOZ1  count: 2
# F  count: 1
# F+sd?  count: 1
# F+sdB  count: 2
# F0  count: 2
# F2+?  count: 1
# F8  count: 1
# F?  count: 1
# G  count: 2
# G0:  count: 1
# G1  count: 1
# G5  count: 2
# G8V  count: 1
# K1  count: 1
# M3-9  count: 1
# M5  count: 1
# M9  count: 1
# O  count: 5
# O3?O4v((f))  count: 1
# O7.5  count: 1
# O7fk  count: 1
# O7fp  count: 1
# O7p  count: 1
# O8p  count: 1
# O9.5  count: 1
# O9.5I  count: 1
# O9.7Ia  count: 1
# O9If  count: 1
# O9k  count: 1
# O?  count: 1
# OB  count: 8
# OB+  count: 5
# OB+e:  count: 1
# OB-  count: 12
# OB-n  count: 1
# OB-nn  count: 2
# OB:  count: 2
# OBe  count: 1
# Oe  count: 1
# Oev:  count: 1
# Ofpe/WN9  count: 1
# Opk  count: 1
# PCyg  count: 1
# PG1159  count: 18
# PG1159/O(He)  count: 4
# SdB+M  count: 1
# WN7  count: 1
# WNE  count: 1
# [WC4]  count: 1
# [WC5]  count: 1
# [WC]  count: 3
# [WO1]  count: 1
# dF  count: 1
# kA1.5hA3mA3Va  count: 1
# nan  count: 0
# sd  count: 141
# sd+  count: 1
# sd:  count: 3
# sdA  count: 1
# sdB  count: 1607
# sdB(+F?)  count: 19
# sdB(?)  count: 1
# sdB(e?)  count: 1
# sdB+  count: 8
# sdB+?  count: 1
# sdB+D  count: 3
# sdB+DA  count: 1
# sdB+F  count: 40
# sdB+F/G  count: 3
# sdB+F0?kA0  count: 1
# sdB+F2:kA2  count: 1
# sdB+F2:kA3  count: 1
# sdB+F2:kA5  count: 1
# sdB+F2?kA2  count: 1
# sdB+F5gF2kA2  count: 1
# sdB+F6V  count: 1
# sdB+F7V  count: 1
# sdB+F8V  count: 1
# sdB+F9  count: 1
# sdB+F?  count: 1
# sdB+G  count: 4
# sdB+G0  count: 1
# sdB+G0IV  count: 1
# sdB+G0V  count: 2
# sdB+G1  count: 2
# sdB+G1V  count: 1
# sdB+G3  count: 1
# sdB+G4  count: 1
# sdB+G4V  count: 1
# sdB+G5  count: 2
# sdB+G7V  count: 1
# sdB+G8  count: 1
# sdB+G9  count: 1
# sdB+G9V  count: 1
# sdB+G:  count: 1
# sdB+K0  count: 1
# sdB+K3  count: 1
# sdB+dM  count: 11
# sdB/A  count: 1
# sdB/B  count: 5
# sdB/B2?  count: 1
# sdB/DA  count: 5
# sdB/OB  count: 3
# sdB/OB?  count: 1
# sdB/OHe  count: 1
# sdB0  count: 1
# sdB0.2VIHe3  count: 1
# sdB0.2VIIHe12  count: 1
# sdB0.2VIIHe3  count: 1
# sdB0.2VIIHe39  count: 1
# sdB0.2VIIHe9  count: 1
# sdB0.2VIIIpHe8  count: 1
# sdB0.2VIeHe7  count: 1
# sdB0.5VHe10  count: 1
# sdB0.5VHe2  count: 1
# sdB0.5VIIHe11  count: 1
# sdB0.5VIIHe18  count: 1
# sdB0.5VIIHe19  count: 1
# sdB0.5VIIHe7  count: 1
# sdB0.5VIIIHe7  count: 1
# sdB0.5VpHe7  count: 1
# sdB0/1  count: 1
# sdB0VIIHe0  count: 1
# sdB0VIIHe8  count: 1
# sdB0VIIHe9  count: 2
# sdB0VIIpHe10  count: 1
# sdB1(k)  count: 1
# sdB1.5VIIHe0  count: 2
# sdB1.5VIIHe1  count: 2
# sdB1.5VIIHe2  count: 3
# sdB1.5VIIHe3  count: 2
# sdB1.5VIIHe4  count: 1
# sdB1.5VIIHe5  count: 1
# sdB1.5VIIHe9  count: 1
# sdB1.5VIIIpHe0  count: 1
# sdB1:  count: 1
# sdB1VIHe0  count: 1
# sdB1VIHe13  count: 1
# sdB1VIIHe0  count: 1
# sdB1VIIHe10  count: 1
# sdB1VIIHe35  count: 1
# sdB1VIIHe39  count: 1
# sdB1VIIHe4  count: 1
# sdB1VIIHe5  count: 1
# sdB1VIIHe6  count: 1
# sdB1VIIHe9  count: 1
# sdB1VIIIHe0  count: 1
# sdB1VIIeHe1  count: 1
# sdB2  count: 4
# sdB2.5IVHe11  count: 1
# sdB2.5VHe7  count: 1
# sdB2.5VIIHe3  count: 1
# sdB2.5VIIeHe3  count: 1
# sdB2VIHe2  count: 2
# sdB2VIHe3  count: 1
# sdB2VIHe4  count: 1
# sdB2VIIHe0  count: 2
# sdB2VIIHe3  count: 4
# sdB2VIIHe4  count: 2
# sdB2VIIHe5  count: 3
# sdB2VIIHe6  count: 1
# sdB2VIIHe7  count: 1
# sdB2VIIIpHe0  count: 1
# sdB2VIIpHe4  count: 1
# sdB3IHe8  count: 2
# sdB3IVHe5  count: 1
# sdB3VHe13  count: 1
# sdB3VHe15  count: 1
# sdB3VIHe6  count: 1
# sdB3VIIHe0  count: 1
# sdB3VIIHe3  count: 2
# sdB3VIIHe4  count: 2
# sdB4  count: 2
# sdB5IIIHe11  count: 1
# sdB5IIIHe4  count: 1
# sdB5IIIHe5  count: 1
# sdB5IIIHe7  count: 1
# sdB5IVHe7  count: 2
# sdB6  count: 1
# sdB7IIIHe3  count: 1
# sdB7IVeHe3  count: 1
# sdB7VHe6  count: 1
# sdB8IIIHe2  count: 1
# sdB8IVHe0  count: 1
# sdB8IVHe1  count: 1
# sdB:  count: 36
# sdB?  count: 20
# sdB?/DA?  count: 1
# sdB?/DAwk?  count: 1
# sdB?He  count: 1
# sdBC0.2VIIHe22  count: 1
# sdBC0.2VIIHe24  count: 1
# sdBC0.2VIIHe26  count: 1
# sdBC0.2VIIHe27  count: 1
# sdBC0.2VIIHe28  count: 1
# sdBC0.5VIIHe28  count: 1
# sdBC1VHe38  count: 1
# sdBC1VIIHe34  count: 1
# sdBC1VIIpHe39  count: 1
# sdBHe  count: 85
# sdBHe+F?  count: 1
# sdBHe0  count: 16
# sdBHe0+F/G  count: 7
# sdBHe1  count: 19
# sdBHe1+F/G  count: 2
# sdBHe1+F/G?  count: 2
# sdBHe:  count: 1
# sdBN0.2VIIHe29  count: 1
# sdBN0.2VIIHe38  count: 1
# sdBN0.2VIIHe39  count: 1
# sdBN0VIIHe28  count: 1
# sdBN0VIIHe35  count: 1
# sdBN0VIIHe37  count: 1
# sdBN0VIIHe38  count: 1
# sdBN0VIIHe39  count: 1
# sdBN1VIIHe37  count: 1
# sdBO  count: 78
# sdBOHe  count: 1
# sdBV  count: 2
# sdBe  count: 1
# sdBe?  count: 1
# sdBp  count: 3
# sdBpec  count: 2
# sdO  count: 334
# sdO(He)  count: 1
# sdO+F  count: 3
# sdO+F/G  count: 1
# sdO+F2:kA1  count: 1
# sdO+F3V  count: 1
# sdO+F6V  count: 1
# sdO+G  count: 1
# sdO+G1V  count: 1
# sdO+G:  count: 1
# sdO+dM  count: 2
# sdO2VIIHe14  count: 1
# sdO2VIIIHe1  count: 1
# sdO2VIIIHe40  count: 2
# sdO2VIIIHe5  count: 1
# sdO2VIeHe11  count: 1
# sdO2VIeHe12  count: 1
# sdO3:  count: 1
# sdO3VIIIpHe1  count: 1
# sdO3VIIeHe40  count: 1
# sdO4He1  count: 1
# sdO4He2  count: 1
# sdO5  count: 1
# sdO5He4  count: 3
# sdO5VIHe1  count: 1
# sdO5VIepHe2  count: 1
# sdO6  count: 1
# sdO6.5VIIpHe35  count: 1
# sdO6He  count: 1
# sdO6He1  count: 3
# sdO6He2  count: 3
# sdO6He4  count: 3
# sdO7  count: 1
# sdO7?He3  count: 1
# sdO7He1  count: 3
# sdO7He1+F/G  count: 1
# sdO7He2  count: 1
# sdO7He3  count: 2
# sdO7VIHe1  count: 1
# sdO7VIIHe1  count: 1
# sdO7VIIHe40  count: 2
# sdO7VIIIHe36  count: 1
# sdO8He1  count: 1
# sdO8He3  count: 1
# sdO8He4  count: 1
# sdO8VIHe1  count: 2
# sdO8VIIHe0  count: 1
# sdO8VIIHe1  count: 2
# sdO8VIIHe40  count: 1
# sdO8VIIIHe0  count: 1
# sdO8VIIIHe5  count: 1
# sdO8VIIIHe7  count: 1
# sdO8VIepHe1  count: 1
# sdO8VpHe19  count: 1
# sdO8p  count: 1
# sdO9VHe17  count: 1
# sdO9VIIHe39  count: 2
# sdO9VIIHe6  count: 1
# sdO9VIIIHe0  count: 1
# sdO9VIIIHe10  count: 1
# sdO:  count: 5
# sdO?  count: 2
# sdO?He  count: 2
# sdOA  count: 52
# sdOA:  count: 1
# sdOB  count: 154
# sdOB+F  count: 3
# sdOB+G  count: 1
# sdOB+G2V  count: 1
# sdOB+G?  count: 1
# sdOB/B  count: 1
# sdOB/O9  count: 1
# sdOB:  count: 3
# sdOB?  count: 2
# sdOBe  count: 1
# sdOC  count: 33
# sdOC1VIIHe40  count: 1
# sdOC2VIIIHe36  count: 1
# sdOC2VIIIHe40  count: 1
# sdOC2VIIeHe40  count: 1
# sdOC2VIeHe40  count: 1
# sdOC6.5VIIHe40  count: 1
# sdOC7VIIHe40  count: 3
# sdOC7VIIeHe40  count: 1
# sdOC8VIIHe39  count: 1
# sdOC9.5VIIHe39  count: 2
# sdOC9VIIHe40  count: 2
# sdOC:  count: 1
# sdOD  count: 9
# sdOHe  count: 211
# sdOHe/DO  count: 1
# sdOe  count: 1
# sdOp  count: 7
# sdOpec  count: 1

# %%
unique_variable_sd = np.unique(df_hot_subluminous['SpTypeSD'].astype(str))

# %%
unique_variable_sd
# Out:
# array(['BHB', 'DAO', 'He-sdB', 'He-sdB+F', 'He-sdB+He-sdB', 'He-sdO',
#        'He-sdO+F', 'He-sdO?', 'He-sdOB', 'He-sdo', 'He.sdOB', 'MS-B',
#        'MS-B/BHB', 'O(H)', 'O(He)', 'PG1159', 'nan', 'sd', 'sd+MS', 'sdB',
#        'sdB+BD', 'sdB+BD?', 'sdB+F', 'sdB+F/G', 'sdB+F6V', 'sdB+F7V',
#        'sdB+F8V', 'sdB+G', 'sdB+G0IV', 'sdB+G0V', 'sdB+G1V', 'sdB+G4V',
#        'sdB+G5V', 'sdB+G7V', 'sdB+G8', 'sdB+G8V', 'sdB+G9V', 'sdB+K',
#        'sdB+K1', 'sdB+K2', 'sdB+K3', 'sdB+K3V', 'sdB+K5', 'sdB+K8',
#        'sdB+MS', 'sdB+MS?', 'sdB+WD', 'sdB+WD?', 'sdB+dM', 'sdB+dM/BD',
#        'sdBV', 'sdBV+F', 'sdBV+F3', 'sdBV+F9', 'sdBV+G0', 'sdBV+G5',
#        'sdBV+MS', 'sdBV+WD', 'sdBV+dM', 'sdO', 'sdO+F', 'sdO+F/G',
#        'sdO+F3V', 'sdO+F?', 'sdO+G', 'sdO+G0V', 'sdO+MS', 'sdO+WD',
#        'sdO+WD?', 'sdO+dMe', 'sdOB', 'sdOB+F', 'sdOB+G', 'sdOB+G2V',
#        'sdOB+K', 'sdOB+MS', 'sdOB+WD', 'sdOB+dM'], dtype=object)

# %%
for vartype in unique_variable_sd:
    v = df_hot_subluminous[df_hot_subluminous['SpTypeSD'] == vartype]
    print(str(vartype) + "  count: "  + str(v.shape[0]))
# Out:
# BHB  count: 14
# DAO  count: 1
# He-sdB  count: 28
# He-sdB+F  count: 1
# He-sdB+He-sdB  count: 1
# He-sdO  count: 372
# He-sdO+F  count: 1
# He-sdO?  count: 1
# He-sdOB  count: 111
# He-sdo  count: 1
# He.sdOB  count: 1
# MS-B  count: 7
# MS-B/BHB  count: 1
# O(H)  count: 3
# O(He)  count: 1
# PG1159  count: 1
# nan  count: 0
# sd  count: 281
# sd+MS  count: 1
# sdB  count: 2147
# sdB+BD  count: 2
# sdB+BD?  count: 1
# sdB+F  count: 48
# sdB+F/G  count: 13
# sdB+F6V  count: 2
# sdB+F7V  count: 1
# sdB+F8V  count: 1
# sdB+G  count: 5
# sdB+G0IV  count: 1
# sdB+G0V  count: 3
# sdB+G1V  count: 1
# sdB+G4V  count: 1
# sdB+G5V  count: 1
# sdB+G7V  count: 1
# sdB+G8  count: 1
# sdB+G8V  count: 1
# sdB+G9V  count: 1
# sdB+K  count: 10
# sdB+K1  count: 3
# sdB+K2  count: 2
# sdB+K3  count: 4
# sdB+K3V  count: 1
# sdB+K5  count: 1
# sdB+K8  count: 1
# sdB+MS  count: 108
# sdB+MS?  count: 2
# sdB+WD  count: 88
# sdB+WD?  count: 5
# sdB+dM  count: 19
# sdB+dM/BD  count: 1
# sdBV  count: 36
# sdBV+F  count: 1
# sdBV+F3  count: 1
# sdBV+F9  count: 1
# sdBV+G0  count: 1
# sdBV+G5  count: 2
# sdBV+MS  count: 1
# sdBV+WD  count: 5
# sdBV+dM  count: 5
# sdO  count: 316
# sdO+F  count: 3
# sdO+F/G  count: 2
# sdO+F3V  count: 1
# sdO+F?  count: 1
# sdO+G  count: 3
# sdO+G0V  count: 1
# sdO+MS  count: 7
# sdO+WD  count: 3
# sdO+WD?  count: 1
# sdO+dMe  count: 1
# sdOB  count: 445
# sdOB+F  count: 3
# sdOB+G  count: 1
# sdOB+G2V  count: 1
# sdOB+K  count: 1
# sdOB+MS  count: 18
# sdOB+WD  count: 4
# sdOB+dM  count: 1

# %%
"""
vartype = 'sdOB+K'

df_variable = df_hot_subluminous[df_hot_subluminous['SpTypeSD'] == vartype][0:1]
df_variable
""";

# %%
"""
SpTypeSim = str(df_variable['SpTypeSim'].iloc[0])
SpTypeSD = str(df_variable['SpTypeSD'].iloc[0])
SpName = str(df_variable['Name'].iloc[0])
""";

# %%
"""
source_id_target = df_variable['source_id'].values[0]
source_id_target
""";

# %%
dfs = df_hot_subluminous.reset_index(drop=True)

# %%
dfs.head()
# Out:
#    Unnamed: 0                     Name                          Gaia  \
# 0           0                    SB937  Gaia DR2 2313054538477276160
# 1           1                   PHL615  Gaia DR2 2414485448212792064
# 2           2               PG2357+174  Gaia DR2 2773760665114010880
# 3           3  UVEXJ000016.27+603246.3   Gaia DR2 429345443672003072
# 4           4              HS2357+2201  Gaia DR2 2847977322031768832
#
#     RAJ2000    DEJ2000        Select SpTypeSim SpTypeSD     Plx    GMAG  \
# 0  0.016782 -33.588654  COLOUR_REDPM        A0      NaN  0.2431  1.1628
# 1  0.021629 -17.147625  COLOUR_REDPM   sdO5He4      sdO  0.2363      --
# 2  0.065659  17.648045  COLOUR_REDPM       sdB      sdB  0.4881  4.9884
# 3  0.067773  60.546199    COLOUR_PLX       sdB      NaN  0.7556  5.9593
# 4  0.076685  22.300821    COLOUR_PLX       sdB      sdB  1.0670  4.3781
#
#         Gmag      BPmag      RPmag   BP-RP   pmRA    pmDE  E_B-V_      AV  \
# 0  14.233900  14.185200  14.246800 -0.0616  4.593 -12.837  0.0125  0.0387
# 1  16.798401  16.550301  17.102800 -0.5526  8.049 -10.354  0.0193  0.0597
# 2  16.545900  16.318899  16.790001 -0.4711  6.468  -2.756  0.0242  0.0749
# 3  16.567801  16.552000  16.438299  0.1138  1.614  -3.009  1.0818  3.3536
# 4  14.236300  14.072500  14.425200 -0.3527  5.517 -11.984  0.0578  0.1793
#
#    FUVmag  NUVmag  VAPASS  BAPASS  gAPASS  rAPASS  iAPASS   uSDSS   gSDSS  \
# 0  16.002  15.593  14.182  14.182  14.086  14.301  14.546      --      --
# 1      --  15.673      --      --      --      --      --      --      --
# 2  15.286  15.479   16.62  16.401  16.348  16.764      --   15.99  16.321
# 3      --   17.41      --      --      --      --      --      --      --
# 4  13.529  13.694  14.283    14.1  14.048  14.441  14.748  13.916  14.007
#
#     rSDSS   iSDSS   zSDSS   uSKYM   vSKYM   gSKYM   rSKYM   iSKYM   zSKYM  \
# 0      --      --      --  15.177  14.394   14.11  14.302  14.607  14.745
# 1      --      --      --  16.195  16.313  16.636  16.957  17.462  17.788
# 2  16.797  17.157  17.445      --      --      --      --      --      --
# 3      --      --      --      --      --      --      --      --      --
# 4  14.425   14.73  15.014      --      --      --      --      --      --
#
#     uATLAS gATLAS   rATLAS   iATLAS   zATLAS uVPHAS gVPHAS r2VPHAS HaVPHAS  \
# 0  14.7445  14.13  14.3948  14.5877  14.6403     --     --      --      --
# 1       --     --       --       --       --     --     --      --      --
# 2       --     --       --       --       --     --     --      --      --
# 3       --     --       --       --       --     --     --      --      --
# 4       --     --       --       --       --     --     --      --      --
#
#   rVPHAS iVPHAS     uKiDS gKiDS rKiDS iKiDS     gPS1     rPS1     iPS1  \
# 0     --     --  14.99557    --    --    --    14.34   14.498  14.5978
# 1     --     --        --    --    --    --   16.602   17.034  17.4196
# 2     --     --        --    --    --    --  16.3488  16.7591  17.1289
# 3     --     --        --    --    --    --  16.6059  16.6535  16.7833
# 4     --     --        --    --    --    --  14.0853  14.4383  14.7667
#
#       zPS1     yPS1 rIPHAS iIPHAS HaIPHAS  J2MASS  H2MASS  K2MASS YUKIDSS  \
# 0   14.819   14.873     --     --      --  14.248   14.17  14.177      --
# 1  17.6887  17.8594     --     --      --      --      --      --      --
# 2  17.3868  17.5781     --     --      --      --      --      --      --
# 3    16.91  17.0069  16.55  16.47   16.43  16.493  16.147  16.049      --
# 4  15.0061  15.1728     --     --      --  14.774  15.076  14.866      --
#
#   JUKIDSS HUKIDSS KUKIDSS      YVHS      JVHS HVHS     KsVHS ZVVV YVVV JVVV  \
# 0      --      --      --        --        --   --        --   --   --   --
# 1      --      --      --  17.38003  17.53805   --  17.78974   --   --   --
# 2      --      --      --        --        --   --        --   --   --   --
# 3      --      --      --        --        --   --        --   --   --   --
# 4      --      --      --        --        --   --        --   --   --   --
#
#   HVVV KsVVV   ZVIKING   YVIKING   JVIKING   HVIKING  KsVIKING   W1mag  \
# 0   --    --  14.19539  14.20024  14.24117  14.28746  14.28081  14.289
# 1   --    --        --        --        --        --        --      --
# 2   --    --        --        --        --        --        --  16.969
# 3   --    --        --        --        --        --        --      --
# 4   --    --        --        --        --        --        --  14.933
#
#     W2mag   W3mag  W4mag        Dens      epsi      sepsi      amax  E_BR_RP_  \
# 0   14.28  12.644   8.75   2484.7498  0.277000  14.520544  0.092586  1.188000
# 1      --      --     --   3024.4438  0.316000   3.537208  0.161034  1.243000
# 2  16.614  12.541  8.889   4105.8315  0.353000   5.738525  0.217278  1.244000
# 3      --      --     --  76111.2340  0.189899   1.505587  0.092514  1.223866
# 4  15.118  12.288  9.105   5186.1606  0.389168  27.937053  0.125877  1.210584
#
#    SED            source_id
# 0  SED  2313054538477276160
# 1  SED  2414485448212792064
# 2  SED  2773760665114010880
# 3  SED   429345443672003072
# 4  SED  2847977322031768832

# %%
gaia_subluminous_list = dfs['source_id'][0:10].to_list()    # Change range as needed but keep is reasonable else Gaia may cancel the connection

gaia_subluminous_list
# Out:
# ['2313054538477276160',
#  '2414485448212792064',
#  '2773760665114010880',
#  '429345443672003072',
#  '2847977322031768832',
#  '2313130542218587008',
#  '2873838557071942016',
#  '2880111438411728256',
#  '565154787767824512',
#  '387152784468510848']

# %%
# RETRIEVE A SET OF SOURCES WITH XP SAMPLED SPECTRA OBAFGKM & CSTAR

for i in range(0, len(gaia_subluminous_list)):
    source_id_target = gaia_subluminous_list[i]
    print("\n")
    query = f"SELECT TOP 10 s.*, p.* \
    FROM gaiadr3.gaia_source AS s \
    join gaiadr3.astrophysical_parameters AS p USING (source_id) \
    WHERE s.has_xp_sampled = 'True' \
    AND p.source_id = " + str(source_id_target)

    job     = Gaia.launch_job_async(query)
    job_results = job.get_results()

    target = job_results.to_pandas()

    results = target['source_id'].values.tolist()
    #print(results)

    if len(results) != 0:
        print("\nGaia XP match found for source_id: " + str(source_id_target))

print("Done!")
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
#
# Gaia XP match found for source_id: 2313054538477276160
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
# Gaia XP match found for source_id: 2847977322031768832
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
#
#
# INFO: Query finished. [astroquery.utils.tap.core]
# Done!

# %%
source_id_target =  '2313054538477276160'    # source_id of a target that has a Gaia XP spectra

# %%
# RETRIEVE A SET OF SOURCES WITH XP SAMPLED SPECTRA OBAFGKM & CSTAR

query = f"SELECT TOP 10 s.*, p.* \
FROM gaiadr3.gaia_source AS s \
join gaiadr3.astrophysical_parameters AS p USING (source_id) \
WHERE s.has_xp_sampled = 'True' \
AND p.source_id = " + str(source_id_target)

job     = Gaia.launch_job_async(query)
job_results = job.get_results()

target = job_results.to_pandas()

results = target['source_id'].values.tolist()
print(results)

print("\nDone!")
# Out:
# INFO: Query finished. [astroquery.utils.tap.core]
# [2313054538477276160]
#
# Done!

# %%
df_variable = df_hot_subluminous[df_hot_subluminous['source_id'] == source_id_target]

df_variable[['Name', 'Gaia' , 'source_id', 'SpTypeSim', 'SpTypeSD']]
# Out:
#     Name                          Gaia            source_id SpTypeSim SpTypeSD
# 0  SB937  Gaia DR2 2313054538477276160  2313054538477276160        A0      NaN

# %%
target['SpT2'] = target.apply(lambda row: starcolorindexSpT.subclass[round(row.bp_rp, 2)], axis=1)

target['SpT2_dereddened'] = target.apply(lambda row: starcolorindexSpT.subclass[round((row.bp_rp - row.ebpminrp_gspphot), 2)], axis=1)

# %%
conditions = [
    (target['logg_gspphot'].astype(float) > 4.20),
    ((target['logg_gspphot'].astype(float) <= 4.20) & (target['logg_gspphot'].astype(float) > 3.90)),
    ((target['logg_gspphot'].astype(float) <= 3.90) & (target['logg_gspphot'].astype(float) > 3.60)),
    ((target['logg_gspphot'].astype(float) < 2.55) & (target['logg_gspphot'].astype(float) > 2.35)),
    (target['logg_gspphot'].astype(float) <= 3.60),
    (target['logg_gspphot'].isna())
]

values = ['main_sequence', 'turnoff', 'subgiants', 'red_clump', 'red_giants', 'unknown']

target['Star_Type'] = np.select(conditions, values)

# %%
cds_portal_flag    = 'N'
simbad_portal_flag = 'Y'
sdss_portal_flag   = 'N'
vizier_portal_flag = 'N'

# %%
for idx in range(0, len(results)):
    print("\n1: " + str(results[idx]) + ' has_xp_sampled: ' + str(target['has_xp_sampled'].iloc[idx]))                        # 1st print statement
    if target['has_xp_sampled'].iloc[idx] == True:
        datalink = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'XP_SAMPLED')
        outputs = [datalink[key][0] for key in datalink.keys()]

        #print("2: " + str(results[idx]) + " Number of stars with XP Spectra: " + str(len(outputs)))                         # 2nd print statement
        if outputs is not None:
            #print("3: " + "outputs is not None")                                                                            # 3rd print statement
            if len(outputs) > 0:
                #print("4: " + "len(outputs): " + str(len(outputs)))                                                         # 4th print statement

                # ====================================================================================
                xRa = str(target['ra'].iloc[idx])
                yDec = str(target['dec'].iloc[idx])
                source_id = str(target['source_id'].iloc[idx])

                print("\n" + "Ra: " + str(xRa))                                                                            
                print("Dec: " + str(yDec))  
                print("\n" + "Source_Id: " + str(source_id) + "\n")              

                if cds_portal_flag == 'Y':
                    cds_portal = 'http://cdsportal.u-strasbg.fr/?target=' + str(xRa) + '%20' + str(yDec)
                    webbrowser.open(cds_portal) 

                if simbad_portal_flag == 'Y':
                    simbad_portal = 'http://simbad.cds.unistra.fr/simbad/sim-coo?Coord=' + str(xRa) + '+' + str(yDec) + \
                                '&CooFrame=FK5&CooEpoch=2000&CooEqui=2000&CooDefinedFrames=none&Radius=2&Radius.unit=arcmin&submit=submit+query'
                    webbrowser.open(simbad_portal)  

                if sdss_portal_flag == 'Y':
                    sdss_portal = 'http://skyserver.sdss.org/dr17/VisualTools/quickobj?ra=' + str(xRa) + '&dec=' + str(yDec)
                    webbrowser.open(sdss_portal)           

                if vizier_portal_flag == 'Y':
                    vizier_portal = 'http://vizier.u-strasbg.fr/viz-bin/VizieR-S?Gaia%20EDR3%20' + str(source_id) 
                    webbrowser.open(vizier_portal)                                          

                result_table = Simbad.query_region(coord.SkyCoord(str(xRa) + " " + str(yDec), 
                    unit=(u.deg, u.deg),frame='icrs'))

                #print("5: " + str(result_table))                                                                            # 5th print statement
                if result_table is not None:
                    if len(result_table) > 0:
                        #print("6: " + "Ra: " + str(xRa))                                                                     # 6th print statement
                        #print("7: " + "Dec: " + str(yDec))                                                                   # 7th print statement

                        for i in range(0, len(result_table['MAIN_ID'])):
                            if i < 5:
                                print(result_table['MAIN_ID'][i])

                        target1 = result_table['MAIN_ID'][0]

                        object = Simbad.query_object(target1)

                        tap_service = vo.dal.TAPService("http://simbad.u-strasbg.fr/simbad/sim-tap")

                        tap_sql = "SELECT main_id, sp_type, otype_txt, otype_longname \
                                        FROM basic JOIN ident ON oidref = oid \
                                            JOIN otypedef ON basic.otype = otypedef.otype \
                                        WHERE id = '" + str(target1) + "';"

                        tap_results = tap_service.search(tap_sql)
                        sptype = tap_results['sp_type']
                        txt = str(sptype).split("=")
                        txt = str(txt).replace("['", "")
                        sp_txt = str(txt).replace("']", "")
                        print("\n" + "Simbad star subclass: " + str(sp_txt))


                print("\n" + "BP_RP star subclass: " + str(target['SpT2'].iloc[idx]))
                print("BP_RP dereddened star subclass: " + str(target['SpT2_dereddened'].iloc[idx]))
                print("classlabel_espels: " + str(target['classlabel_espels'].iloc[idx]))
                print("Star Type: " + str(target['Star_Type'].iloc[idx]))
                print("SpTypeSim: " +  str(SpTypeSim))
                print("SpTypeSD: " +  str(SpTypeSD))
                print("SpName: " +  str(SpName))
                #print('\nasassn_name: ' + str(df_variable[['asassn_name']].values))
                #print('other_names: ' + str(df_variable[['other_names']].values))
                #print("\nASAS_SN Variable Type: " + str(ASASSN_Variable_Type) + '\n' )
                #print("Star Distance [pc]: " + str(int(target['distance_gspphot'].iloc[idx])))
                #print("Star Distance [light years]: " + str(int(target['distance_gspphot'].iloc[idx] * 3.26156)) + "\n")

                # ====================================================================================


                xp      = outputs[0].to_table()                       

                # Add flux-density columns ============================
                xp['flux_jy']         = xp['flux'].to(u.Jansky, equivalencies = u.spectral_density(xp['wavelength'].value * xp['wavelength'].unit))
                xp['flux_mjy']        = xp['flux_jy'].to(u.millijansky)
                xp['flux_mjy'].format = '7.4f'
                
                # =========
                
                #display(xp)

                # =========

                fig       = plt.figure(figsize=[20,10])

                yRangeMax = float(xp['flux'].max())

                plt.plot(xp['wavelength']*10, xp['flux']/yRangeMax * 2, linewidth = 2, marker='o', markerfacecolor='red') 
                plt.title('XP_SAMPLED Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                ' \nLogG: ' + str(round(target['logg_gspphot'].iloc[idx], 2)) + 
                '    Teff: ' + str(round(target['teff_gspphot'].iloc[idx],0)) +
                '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                '    [M/H]: ' + str(round(target['mh_gspphot'].iloc[idx],2)) +
                '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                ' \nSource_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                if make_canvas_flag == "Y":
                    make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", 
                                fontsize = 12)
                #else:
                    #make_labels()

                if hydrogen_lines_flag == "Y":
                    Hydrogen_lines(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", 
                                   fontsize = 12)

                plt.show()
                
                    
        print("\n" + str(results[idx]) + ' has_rvs: ' + str(target['has_rvs'].iloc[idx]) + "\n")
        if target['has_rvs'].iloc[idx] == True:
            datalinkRVS = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'RVS')
            outputsRVS = [datalinkRVS[key][0] for key in datalinkRVS.keys()]
            #print("datalinkRVS: " + str(datalinkRVS))

            if outputsRVS is not None:
                if len(outputsRVS) >0:
                    xpRVS      = outputsRVS[0].to_table()

                    # =========
                
                    #display(xpRVS)

                    # =========

                    fig       = plt.figure(figsize=[20,10])

                    yRangeMax = float(xpRVS['flux'].max())

                    plt.plot(xpRVS['wavelength']*10, xpRVS['flux']/yRangeMax * 2, linewidth = 2, marker='.', markerfacecolor='red') 
                    plt.title('RVS Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                    ' \nLogG: ' + str(round(target['logg_gspspec'].iloc[idx], 2)) + 
                    '    Teff: ' + str(round(target['teff_gspspec'].iloc[idx],0)) +
                    '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                    '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                    '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                    '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                    '    [M/H]: ' + str(round(target['mh_gspspec'].iloc[idx],2)) +
                    '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                    '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                    ' \nSource_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                    if make_canvas_flag == "Y":
                        #make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)
                        #make_labels()
                        make_RVS_canvas()
                        
                    plt.show()


                    fig       = plt.figure(figsize=[20,10])

                    yRangeMax = float(xpRVS['flux'].max())

                    plt.plot(xpRVS['wavelength']*10, xpRVS['flux']/yRangeMax * 2, linewidth = 2, marker='.', markerfacecolor='red') 
                    plt.title('RVS Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                    ' \nLogG: ' + str(round(target['logg_gspspec'].iloc[idx], 2)) + 
                    '    Teff: ' + str(round(target['teff_gspspec'].iloc[idx],0)) +
                    '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                    '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                    '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                    '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                    '    [M/H]: ' + str(round(target['mh_gspspec'].iloc[idx],2)) +
                    '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                    '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                    ' \nSource_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                    plt.xlim(8460, 8580)

                    if make_canvas_flag == "Y":
                        #make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)
                        #make_labels()
                        make_RVS_canvas1()
                        
                    plt.show()


                    fig       = plt.figure(figsize=[20,10])

                    yRangeMax = float(xpRVS['flux'].max())

                    plt.plot(xpRVS['wavelength']*10, xpRVS['flux']/yRangeMax * 2, linewidth = 2, marker='.', markerfacecolor='red') 
                    plt.title('RVS Spectra Gaia DR3 Class '+ str(target['spectraltype_esphs'].iloc[idx]) + 
                    ' \nLogG: ' + str(round(target['logg_gspspec'].iloc[idx], 2)) + 
                    '    Teff: ' + str(round(target['teff_gspspec'].iloc[idx],0)) +
                    '    Mass: ' + str(round(target['mass_flame'].iloc[idx],2)) +
                    '    Luminosity: ' + str(round(target['lum_flame'].iloc[idx],2)) +
                    '    Radius: ' + str(round(target['radius_gspphot'].iloc[idx],2)) +
                    '    Age: ' + str(round(target['age_flame'].iloc[idx],2)) +
                    '    [M/H]: ' + str(round(target['mh_gspspec'].iloc[idx],2)) +
                    '    [Alpha/Fe]: ' + str(round(target['alphafe_gspspec'].iloc[idx],2)) +
                    '\nRa: ' + str(target['ra'].iloc[idx]) + "    Dec: " + str(target['dec'].iloc[idx]) +
                    ' \nSource_ID: ' + str(target['source_id'].iloc[idx]), fontsize=15)

                    plt.xlim(8580, 8700)

                    if make_canvas_flag == "Y":
                        #make_canvas(xlabel = f"Wavelength [{xp['wavelength'].unit}]", ylabel = f"Flux [{xp['flux'].unit}]", fontsize = 12)
                        #make_labels()
                        make_RVS_canvas2()
                        
                    plt.show()


        #print(str(results[idx]) + ' has_xp_continuous: ' + str(target['has_xp_continuouss'].iloc[idx]))
        if target['has_xp_continuous'].iloc[idx] == True:
            datalinkXPC = Gaia.load_data(results[idx], data_structure = 'INDIVIDUAL', retrieval_type = 'XP_CONTINUOUS')
            outputsXPC = [datalinkXPC[key][0] for key in datalinkXPC.keys()]
            #print("datalinkXPC: " + str(datalinkXPC))

           

print("\nDone!")
# Out:
# 1: 2313054538477276160 has_xp_sampled: True
#
# Ra: 0.01680667256473109
# Dec: -33.58871133460496
#
# Source_Id: 2313054538477276160
#
# SB 937
# 2dFGRS TGS494Z227
#
# Simbad star subclass: ["A0' 'A0"]
#
# BP_RP star subclass: A0
# BP_RP dereddened star subclass: B9.5
# classlabel_espels:
# Star Type: red_giants
# SpTypeSim: nan
# SpTypeSD: sdOB+K
# SpName: HS0127+3146
# 2313054538477276160 has_rvs: False
#
#
# Done!
